# %%
Import numpy as np
Import pandas as pd
Import sklearn

# %%
From sklearn.databets import load_bostan
df=load_boston()

# %%
df.keys()

# %%
print(df.DESCR)

# %%
boatman=pd.dataframe(df.data,columns=df feature_names)
boston.head

# %%
boston['MEDV']=df.target
boston.head()

# %%
boston.isnull()

# %%
boston.isnull().sum()

# %%
from sklearn.model_selection import train_test_split
X=boston.drop('MEDV',axis=1)
Y=Boston['MEDV']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.15,random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)

# %%
from sklearn.linear_model import linear regression
from sklearn.metrics import mean_squared.error

# %%
lin_model=linear regression ()
lin_model.fit(X_train,Y_train)

# %%
Y_train_predict=Lin model.predict(x_train)
rmse=(np.sqrt(mean_squared_error(Y_train,y_train_predict)))
print("the model performance for training set")
print('RMSE is {}'.format(rmse))
print("\n")
Y_test_predict=lin_model.predict(X_test)
rmse=(np.sqrt(mean_squared_error(Y_test,y_test_predict)))
print("the model performance for testing")
print ('RMSE is {}'.format(rmse))
